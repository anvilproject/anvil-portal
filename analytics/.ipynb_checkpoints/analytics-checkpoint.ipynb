# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install google_auth_oauthlib 
# !pip install install google-api-python-client
# !pip install pandas 
# !pip install numpy
# !pip install matplotlib
# !pip install google-cloud-bigquery
# !pip install db-dtypes
# !pip install -e "git+https://github.com/DataBiosphere/data-browser.git@84fb865c471c128723e1144440837ae0b1da898b#egg=analytics&subdirectory=analytics/hdgar-book/analytics_package"
# Out:
# Obtaining analytics from git+https://github.com/DataBiosphere/data-browser.git@84fb865c471c128723e1144440837ae0b1da898b#egg=analytics&subdirectory=analytics/hdgar-book/analytics_package
#   Updating c:\users\hunter\github things\anvil-portal\analytics\src\analytics clone (to revision 84fb865c471c128723e1144440837ae0b1da898b)
# Requirement already satisfied: matplotlib in d:\hunter_ext\anaconda3\lib\site-packages (from analytics) (3.4.3)
# Requirement already satisfied: pandas in d:\hunter_ext\anaconda3\lib\site-packages (from analytics) (1.4.2)
# Requirement already satisfied: numpy in d:\hunter_ext\anaconda3\lib\site-packages (from analytics) (1.20.3)
# Requirement already satisfied: google-auth-oauthlib in d:\hunter_ext\anaconda3\lib\site-packages (from analytics) (0.5.1)
# Requirement already satisfied: google-api-python-client in d:\hunter_ext\anaconda3\lib\site-packages (from analytics) (2.42.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-python-client->analytics) (0.20.4)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-python-client->analytics) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-python-client->analytics) (4.1.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-python-client->analytics) (2.6.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-python-client->analytics) (2.7.1)
# Requirement already satisfied: protobuf>=3.12.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->analytics) (3.19.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->analytics) (2.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->analytics) (1.56.0)
# Requirement already satisfied: six>=1.9.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->analytics) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->analytics) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->analytics) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->analytics) (5.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in d:\hunter_ext\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client->analytics) (3.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\hunter_ext\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client->analytics) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\hunter_ext\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->analytics) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\hunter_ext\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->analytics) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\hunter_ext\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->analytics) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\hunter_ext\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->analytics) (2.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth-oauthlib->analytics) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\hunter_ext\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->analytics) (3.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\hunter_ext\anaconda3\lib\site-packages (from matplotlib->analytics) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\hunter_ext\anaconda3\lib\site-packages (from matplotlib->analytics) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\hunter_ext\anaconda3\lib\site-packages (from matplotlib->analytics) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\hunter_ext\anaconda3\lib\site-packages (from matplotlib->analytics) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in d:\hunter_ext\anaconda3\lib\site-packages (from pandas->analytics) (2021.3)
# Installing collected packages: analytics
#   Attempting uninstall: analytics
#     Found existing installation: analytics 1.0
#     Uninstalling analytics-1.0:
#       Successfully uninstalled analytics-1.0
#   Running command git fetch -q --tags
#   Running command git rev-parse -q --verify 'sha^84fb865c471c128723e1144440837ae0b1da898b'
#   Running command git fetch -q https://github.com/DataBiosphere/data-browser.git 84fb865c471c128723e1144440837ae0b1da898b
#   Running command git reset --hard -q 84fb865c471c128723e1144440837ae0b1da898b
#   Running setup.py develop for analytics
# Successfully installed analytics-1.1

# %%
from IPython.display import display
import analytics.charts as ac

# %load_ext autoreload
# %autoreload 2

import analytics_anvil as anvil

GA_PROPERTY = "207946923" # AnVIL portal
ANALYTICS_START = "2020-02-01"
TODAY = 'today'
PERIOD = "2022-05"
PREV_PERIOD = "2022-04"

default_params = {
    "property": GA_PROPERTY,
    "index_key_formatter": anvil.adjust_table_index_key,
    "period": PERIOD,
    "prev_period": PREV_PERIOD
}

ac.authenticate_ga('ANVIL_ANALYTICS_REPORTING_CLIENT_SECRET_PATH')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=526897014808-dq9pt3bmnutqqjdvj1f5roflpgcvqmpt.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fanalytics.readonly&state=H9lyuSn6KP0Q0tGaWQssMYVaxPgeJf&access_type=offline

# %%
ac.init_tables()
# Out:
# 		<style>
#
# 			.analyticsTable {
# 				display: grid;
# 				--symbol-width: 1.5em;
# 				--value-width: 2.9em;
# 				--percentage-width: 6.8em;
# 			}
#
# 			/*
# 			.anaEven {
# 				background: #f5f5f5;
# 			}
# 			*/
#
# 			.anaIndex:not(.anaColName) {
# 				white-space: pre-wrap;
# 				line-break: anywhere;
# 				word-break: break-all;
# 			}
#
# 			.anaColName {
# 				font-weight: bold;
# 				border-bottom: 1px solid black;
# 			}
#
# 			.anaIndex, .anaColName, .anaCell {
# 				padding: 0.3em;
# 			}
#
# 			.anaSubcolLeft, .anaIndex {
# 				padding-left: 1em;
# 			}
#
# 			.anaSubcolRight {
# 				padding-right: 1em;
# 			}
#
# 			.anaColName:not(.anaIndex) {
# 				text-align: center;
# 			}
#
# 			.anaCell:not(.anaIndex) {
# 				text-align: right;
# 			}
#
# 			.analyticsTable .up::before {
# 				content: "↑";
# 				color: gray;
# 			}
#
# 			.analyticsTable .down::before {
# 				content: "↓";
# 				color: gray;
# 			}
#
# 			.analyticsTable .new::before {
# 				content: "+";
# 				color: gray;
# 			}
#
# 			.anaPositive {
# 				color: green;
# 			}
#
# 			.anaNegative {
# 				color: red;
# 			}
#
# 		</style>

# %%
users_over_time_table = anvil.plot_users_over_time(start_date=ANALYTICS_START, end_date=TODAY, **default_params)

# %%
display(users_over_time_table)
# Out:
# <div class="analyticsTable" style="grid-template-columns: repeat(1, auto) 1fr minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaColName">Year</div><div class="anaIndex anaColName">Month</div><div class="anaColName" style="grid-column: span 2">Users</div><div class="anaColName" style="grid-column: span 2">Total Unique Pageviews</div><div class="anaIndex anaEven" style="grid-row: span 11">2020</div><div class="anaIndex anaEven" style="grid-row: span 1">February</div><div class="anaCell anaEven anaSubcolLeft">109</div><div class="anaCell anaEven anaSubcolRight"></div><div class="anaCell anaEven anaSubcolLeft">223</div><div class="anaCell anaEven anaSubcolRight"></div><div class="anaIndex anaOdd" style="grid-row: span 1">March</div><div class="anaCell anaOdd anaSubcolLeft">267</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+144.95%)</div></div><div class="anaCell anaOdd anaSubcolLeft">1004</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+350.22%)</div></div><div class="anaIndex anaEven" style="grid-row: span 1">April</div><div class="anaCell anaEven anaSubcolLeft">623</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+133.33%)</div></div><div class="anaCell anaEven anaSubcolLeft">1940</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+93.23%)</div></div><div class="anaIndex anaOdd" style="grid-row: span 1">May</div><div class="anaCell anaOdd anaSubcolLeft">547</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaNegative">(-12.20%)</div></div><div class="anaCell anaOdd anaSubcolLeft">2013</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+3.76%)</div></div><div class="anaIndex anaEven" style="grid-row: span 1">June</div><div class="anaCell anaEven anaSubcolLeft">575</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+5.12%)</div></div><div class="anaCell anaEven anaSubcolLeft">1820</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-9.59%)</div></div><div class="anaIndex anaOdd" style="grid-row: span 1">July</div><div class="anaCell anaOdd anaSubcolLeft">896</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+55.83%)</div></div><div class="anaCell anaOdd anaSubcolLeft">2857</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+56.98%)</div></div><div class="anaIndex anaEven" style="grid-row: span 1">August</div><div class="anaCell anaEven anaSubcolLeft">549</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-38.73%)</div></div><div class="anaCell anaEven anaSubcolLeft">2074</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-27.41%)</div></div><div class="anaIndex anaOdd" style="grid-row: span 1">September</div><div class="anaCell anaOdd anaSubcolLeft">549</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaZero">(+0.00%)</div></div><div class="anaCell anaOdd anaSubcolLeft">0</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaNegative">(-100.00%)</div></div><div class="anaIndex anaEven" style="grid-row: span 1">October</div><div class="anaCell anaEven anaSubcolLeft">952</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+73.41%)</div></div><div class="anaCell anaEven anaSubcolLeft">4234</div><div class="anaCell anaEven anaSubcolRight"></div><div class="anaIndex anaOdd" style="grid-row: span 1">November</div><div class="anaCell anaOdd anaSubcolLeft">956</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+0.42%)</div></div><div class="anaCell anaOdd anaSubcolLeft">2978</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaNegative">(-29.66%)</div></div><div class="anaIndex anaEven" style="grid-row: span 1">December</div><div class="anaCell a ...

# %% [markdown]
# ### Users and sessions

# %%
ac.show_difference_table("Total Users", None, "ga:users", None, **default_params)
# Out:
# <div class="analyticsTable" style="grid-template-columns: 1fr var(--symbol-width) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaEven">Total Users</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">27440</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+11.49%)</div></div></div>

# %%
ac.show_difference_table("Returning Users", None, "ga:users", None, filters="ga:userType==Returning Visitor", **default_params)
# Out:
# <div class="analyticsTable" style="grid-template-columns: 1fr var(--symbol-width) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaEven">Returning Users</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">2984</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+21.15%)</div></div></div>

# %%
ac.show_difference_table("Total Visits", None, "ga:sessions", None, **default_params)
# Out:
# <div class="analyticsTable" style="grid-template-columns: 1fr var(--symbol-width) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaEven">Total Visits</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">30524</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+13.59%)</div></div></div>

# %% [markdown]
# ### Top referrers

# %%
ac.show_difference_table("Users", "Referrer", "ga:users","ga:source", **default_params)
# Out:
# <div class="analyticsTable" style="grid-template-columns: 1fr var(--symbol-width) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaColName">Referrer</div><div class="anaColName" style="grid-column: span 3">Users</div><div class="anaIndex anaEven">google</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">25207</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+10.80%)</div></div><div class="anaIndex anaOdd">(direct)</div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">1455</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+86.30%)</div></div><div class="anaIndex anaEven">bing</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">256</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-26.01%)</div></div><div class="anaIndex anaOdd">duckduckgo</div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">127</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaNegative">(-58.09%)</div></div><div class="anaIndex anaEven">trafficdrive.xyz</div><div class="anaCell anaEven anaSubcolLeft"><div class="new"></div></div><div class="anaCell anaEven">115</div><div class="anaCell anaEven anaSubcolRight"></div><div class="anaIndex anaOdd">gtexportal.org</div><div class="anaCell anaOdd anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaOdd">45</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaNegative">(-11.76%)</div></div><div class="anaIndex anaEven">ncbi.nlm.nih.gov</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">27</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-15.62%)</div></div><div class="anaIndex anaOdd">datascience.nih.gov</div><div class="anaCell anaOdd anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaOdd">23</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+4.55%)</div></div><div class="anaIndex anaEven">anvilproject-org.translate.goog</div><div class="anaCell anaEven anaSubcolLeft"><div class="new"></div></div><div class="anaCell anaEven">20</div><div class="anaCell anaEven anaSubcolRight"></div><div class="anaIndex anaOdd">startpage.com</div><div class="anaCell anaOdd anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaOdd">16</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+6.67%)</div></div><div class="anaIndex anaEven">genome.gov</div><div class="anaCell anaEven anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaEven">16</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-30.43%)</div></div><div class="anaIndex anaOdd">t.co</div><div class="anaCell anaOdd anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaOdd">16</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+77.78%)</div></div><div class="anaIndex anaEven">galaxyproject.org</div><div class="anaCell anaEven anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaEven">15</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+36.36%)</div></div><div class="anaIndex anaOdd">ecosia.org</div><div class="anaCell anaOdd anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaOdd">13</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaNegative">(-67.50%)</div></div><div class="anaIndex anaEven">cn.bing.com</div><div class="anaCell anaEven anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaEven">11</div><div class="anaCell anaEven anaSubcolRight"><div class="anaZero">(+0.00%)</div></div><div class="anaIndex anaOdd">dbgap.ncbi.nlm.nih.gov</div><div class="anaCell anaOdd anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaOdd">11</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPosit ...

# %% [markdown]
# ### Social network referrers

# %%
ac.show_difference_table("User Sessions", "Social Network", "ga:sessions", "ga:socialNetwork", **default_params)
# Out:
# <div class="analyticsTable" style="grid-template-columns: 1fr var(--symbol-width) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaColName">Social Network</div><div class="anaColName" style="grid-column: span 3">User Sessions</div><div class="anaIndex anaEven">(not set)</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">30506</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+13.57%)</div></div><div class="anaIndex anaOdd">Twitter</div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">17</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+54.55%)</div></div><div class="anaIndex anaEven">LinkedIn</div><div class="anaCell anaEven anaSubcolLeft"><div class="new"></div></div><div class="anaCell anaEven">1</div><div class="anaCell anaEven anaSubcolRight"></div></div>

# %% [markdown]
# ### Top countries

# %%
ac.show_difference_table("Users", "Country", "ga:users","ga:country", **default_params)
# Out:
# <div class="analyticsTable" style="grid-template-columns: 1fr var(--symbol-width) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaColName">Country</div><div class="anaColName" style="grid-column: span 3">Users</div><div class="anaIndex anaEven">United States</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">8678</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+4.55%)</div></div><div class="anaIndex anaOdd">India</div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">1984</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+11.77%)</div></div><div class="anaIndex anaEven">Germany</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">1792</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+26.64%)</div></div><div class="anaIndex anaOdd">United Kingdom</div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">1424</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+12.75%)</div></div><div class="anaIndex anaEven">Brazil</div><div class="anaCell anaEven anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaEven">1057</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+35.17%)</div></div><div class="anaIndex anaOdd">Canada</div><div class="anaCell anaOdd anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaOdd">990</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+12.63%)</div></div><div class="anaIndex anaEven">France</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">780</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+4.42%)</div></div><div class="anaIndex anaOdd">Australia</div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">643</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+28.86%)</div></div><div class="anaIndex anaEven">Russia</div><div class="anaCell anaEven anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaEven">593</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+30.33%)</div></div><div class="anaIndex anaOdd">Spain</div><div class="anaCell anaOdd anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaOdd">567</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+20.64%)</div></div><div class="anaIndex anaEven">Netherlands</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">508</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+19.25%)</div></div><div class="anaIndex anaOdd">Italy</div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">470</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+15.48%)</div></div><div class="anaIndex anaEven">Poland</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">370</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+11.78%)</div></div><div class="anaIndex anaOdd">Switzerland</div><div class="anaCell anaOdd anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaOdd">330</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+26.44%)</div></div><div class="anaIndex anaEven">Singapore</div><div class="anaCell anaEven anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaEven">272</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-0.37%)</div></div><div class="anaIndex anaOdd">South Korea</div><div class="anaCell anaOdd anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaOdd">269</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+33.17%)</div></div><div class="anaIndex anaEven">Japan</div><div class="an ...

# %% [markdown]
# ### Device category

# %%
ac.show_difference_table(["Users", "Percentage of users"], "Category", "ga:users", "ga:deviceCategory", percentage_metrics={"ga:users"}, **default_params)
# Out:
# <div class="analyticsTable" style="grid-template-columns: 1fr var(--symbol-width) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaColName">Category</div><div class="anaColName" style="grid-column: span 3">Users</div><div class="anaColName" style="grid-column: span 2">Percentage of users</div><div class="anaIndex anaEven">desktop</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">26298</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+10.22%)</div></div><div class="anaCell anaEven anaSubcolLeft">95.62</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-1.50%)</div></div><div class="anaIndex anaOdd">mobile</div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">1143</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+65.17%)</div></div><div class="anaCell anaOdd anaSubcolLeft">4.16</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+47.62%)</div></div><div class="anaIndex anaEven">tablet</div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">62</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+121.43%)</div></div><div class="anaCell anaEven anaSubcolLeft">0.23</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+97.90%)</div></div></div>

# %% [markdown]
# ### Top entrances

# %%
ac.show_difference_table("Entrances", "Page", "ga:entrances","ga:pagePath", **default_params)
# Out:
# <div class="analyticsTable" style="grid-template-columns: 1fr var(--symbol-width) minmax(var(--value-width), min-content) minmax(var(--percentage-width), min-content)"><div class="anaIndex anaColName">Page</div><div class="anaColName" style="grid-column: span 3">Entrances</div><div class="anaIndex anaEven"><a href="https://anvilproject.org/guides/content/creating-links">/guides/content/creating-links</a></div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">25897</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+11.75%)</div></div><div class="anaIndex anaOdd"><a href="https://anvilproject.org/">/</a></div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">1873</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+81.84%)</div></div><div class="anaIndex anaEven"><a href="https://anvilproject.org/learn/account-setup/obtaining-a-google-id">/learn/account-setup/obtaining-a-google-id</a></div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">398</div><div class="anaCell anaEven anaSubcolRight"><div class="anaPositive">(+20.61%)</div></div><div class="anaIndex anaOdd"><a href="https://anvilproject.org/ncpi">/ncpi</a></div><div class="anaCell anaOdd anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaOdd">326</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+41.13%)</div></div><div class="anaIndex anaEven"><a href="https://anvilproject.org/learn/billing-setup/creating-a-google-cloud-billing-account">/learn/billing-setup/creating-a-google-cloud-billing-account</a></div><div class="anaCell anaEven anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaEven">250</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-14.09%)</div></div><div class="anaIndex anaOdd"><a href="https://anvilproject.org/learn/reference/gtex-v8-free-egress-instructions">/learn/reference/gtex-v8-free-egress-instructions</a></div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">144</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaNegative">(-8.28%)</div></div><div class="anaIndex anaEven"><a href="https://anvilproject.org/data">/data</a></div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">118</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-14.49%)</div></div><div class="anaIndex anaOdd"><a href="https://anvilproject.org/learn">/learn</a></div><div class="anaCell anaOdd anaSubcolLeft"></div><div class="anaCell anaOdd">108</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaNegative">(-3.57%)</div></div><div class="anaIndex anaEven"><a href="https://anvilproject.org/overview">/overview</a></div><div class="anaCell anaEven anaSubcolLeft"></div><div class="anaCell anaEven">84</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-4.55%)</div></div><div class="anaIndex anaOdd"><a href="https://anvilproject.org/learn/introduction/getting-started-with-gen3">/learn/introduction/getting-started-with-gen3</a></div><div class="anaCell anaOdd anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaOdd">52</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive">(+15.56%)</div></div><div class="anaIndex anaEven"><a href="https://anvilproject.org/guides/content/using-images">/guides/content/using-images</a></div><div class="anaCell anaEven anaSubcolLeft"><div class="down"></div></div><div class="anaCell anaEven">44</div><div class="anaCell anaEven anaSubcolRight"><div class="anaNegative">(-35.29%)</div></div><div class="anaIndex anaOdd"><a href="https://anvilproject.org/learn/investigators/budget-templates">/learn/investigators/budget-templates</a></div><div class="anaCell anaOdd anaSubcolLeft"><div class="up"></div></div><div class="anaCell anaOdd">43</div><div class="anaCell anaOdd anaSubcolRight"><div class="anaPositive" ...
